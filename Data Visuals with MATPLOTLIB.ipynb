# %%
from matplotlib import pyplot as plt


years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

plt.title("Nominal GDP") #title of chart
plt.xlabel("Years") # X axis label
plt.ylabel("Billions of $") #y axis lable

plt.plot(years, gdp, color='green', marker='o', linestyle='-.') 
#line of code which plots Graph. The first variable is the axis by default, 
#second variable are he values which will construct the Y axis
#third and fourth self explainatory;
#fifth line stye which can vary

# %%
movies = ["Annie Hall", "Ben-Hur", "Casablanca", "Gandhi", "West Side Story"]
num_oscars = [5, 11, 3, 8, 10]


plt.bar(movies, num_oscars, color='grey')
plt.ylabel("# of Academy Awards")
plt.title("My Favorite Movies")
# Out:
# Text(0.5, 1.0, 'My Favorite Movies')

# %%
from collections import Counter

grades = [83,95,91,87,70,0,85,82,100,67,73,77,0]
decile = lambda grade: grade // 10 * 10
histogram = Counter(decile(grade) for grade in grades)

plt.bar([x + 0 for x in histogram.keys()], 
histogram.values(), 8)

plt.axis([-5, 105, 0, 5])

plt.xticks([10 * i for i in range(11)])

plt.xlabel("Decile")
plt.ylabel("# of Students")
plt.title("Distribution of Exam 1 Grades")

##NEW FUNCTION ALERT!!!
##Lamda Function is used here
##A lamba function is an anonymous function which can be used in functions which require inputs of a function and another input
##In this case the decile variables creates deciles from the items in grades
##this is done by using  a lambda function using the input grade (can be anyname) , dividing it by 10 rounding down (//)
##then multiplying by 10 eg 83 // 10 = 8, 8 * 10 is 80. 

##the lambda function is then applied to variable grade in a for loop looping through the list of grades. 
##Grade was chosen as the variable name in the for loop to match the lambda input. As you know for a for loop any variable
##name can be chose.

##this functions and for loop was encapsulated with the counter function, which counts the number of instances of a decile
##creates a dictionary, using the deciles as keys and the instances as values
# Out:
# dict_keys([80, 90, 70, 0, 100, 60])

# %%
variance = [1, 2, 4, 8, 16, 32, 64, 128, 256]
bias_squared = [256, 128, 64, 32, 16, 8, 4, 2, 1]
total_error = [x + y for x, y in zip(variance, bias_squared)]
xs = [i for i, _ in enumerate(variance)]
# we can make multiple calls to plt.plot
# to show multiple series on the same chart
plt.plot(xs, variance, 'g-', label='variance') # green solid line
plt.plot(xs, bias_squared, 'r-.', label='bias^2') # red dot-dashed line
plt.plot(xs, total_error, 'b:', label='total error') # blue dotted line
# because we've assigned labels to each series
# we can get a legend for free
# loc=9 means "top center"
plt.legend(loc=9)
plt.xlabel("model complexity")
plt.title("The Bias-Variance Tradeoff")
plt.show()

##NEW FUNCTION ALERT
#enumerate results in the indexes of each element and the elemment in a list. 
##i for i in enumerate(variance)
##would result in [(0, 1), (1, 2), (2, 4), (3, 8), (4, 16), (5, 32), (6, 64), (7, 128), (8, 256)]
##Using the _ in the for loop would capture only the index.In this case it was used to be the x axis in the chart


#zip adds each element from one list to each element to another which can then be placed in a new list

# %%
friends = [ 70, 65, 72, 63, 71, 64, 60, 64, 67]
minutes = [175, 170, 205, 120, 220, 130, 105, 145, 190]
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i']

plt.scatter(friends, minutes)

for label, friend_count, minute_count in zip(labels, friends, minutes):
    plt.annotate(label,
        xy=(friend_count, minute_count), # put the label with its point
        xytext=(5, -5), # but slightly offset
        textcoords='offset points')
plt.title("Daily Minutes vs. Number of Friends")
# Out:
# [('a', 70, 175), ('b', 65, 170), ('c', 72, 205), ('d', 63, 120), ('e', 71, 220), ('f', 64, 130), ('g', 60, 105), ('h', 64, 145), ('i', 67, 190)]

# %%
test_1_grades = [ 99, 90, 85, 97, 80]
test_2_grades = [100, 85, 60, 90, 70]
plt.scatter(test_1_grades, test_2_grades)
plt.xlabel("test 1 grade")
plt.ylabel("test 2 grade")
plt.axis([0, 100, 0, 100]) ## sets the range of both the X and Y axis
plt.xticks([10 * i for i in range(11)]) ## makes the x axis increase by 10
plt.yticks([10 * i for i in range(11)]) ## makes the 7 axis increase by 10
plt.show()

Useful code breakdown
## [10 * i for i in range(11)] is a quick way of getting numbers 0 to 10 in intervals of 

##for i in range(11) loops from numbers 0 to 10
##combining it 10 * i to the above will multiply each number 0 to 10 by 10 resulting i 0 to 100
##placing it in [] creates a list
##putting the code in plt.xticks results in the x axis being from 0 to 100 with intervals of 10
